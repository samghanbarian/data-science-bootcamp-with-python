# %% [markdown]
# ## Data
# The data from Goodread website is used fro this analysis, which is scrapped by researchers at UCSD.
# [link to data](https://sites.google.com/eng.ucsd.edu/ucsdbookgraph/home)

# %%
#number of lines in the json file
# !wc -l goodreads_books.json.gz
# Out:
# 'wc' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !ls -lh | grep goodreads_books.json.gz
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#read the json file without unzipping
import gzip
import json
import pandas as pd


with gzip.open('book-recommendation/goodreads_books.json.gz', 'r') as f:
    l = f.readline()

# %%
l
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %%
def parse_fields(line):
    line = json.loads(line) #load streams
    return{
        'book_id':line['book_id'],
        'title':line['title_without_series'],
        'rating' : line['ratings_count'],
        'url' : line['url'],
        'book_cover': line['image_url']
    }

# %%
book_titles = []
with gzip.open('book-recommendation/goodreads_books.json.gz', 'r') as f:
    while True:
        l = f.readline()
        if not l:
            break
        fileld = parse_fields(l)
        #throw an error in rating filed is empty
        try:
            rating = int(fileld['rating'])
        except ValueError:
            continue
        
        #consider books with more than 5 ratings
        if rating > 5:
            book_titles.append(fileld)

# %%
titles = pd.DataFrame.from_dict(book_titles)

# %%
titles.head(4)
# Out:
#    book_id                                              title rating  \
# 0  1333909                                        Good Harbor     10
# 1  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...    140
# 2  6066819                               Best Friends Forever  51184
# 3   287140  Runic Astrology: Starcraft and Timekeeping in ...     15
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1333909.Go...
# 1  https://www.goodreads.com/book/show/7327624-th...
# 2  https://www.goodreads.com/book/show/6066819-be...
# 3  https://www.goodreads.com/book/show/287140.Run...
#
#                                           book_cover
# 0  https://s.gr-assets.com/assets/nophoto/book/11...
# 1  https://images.gr-assets.com/books/1304100136m...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1413219371m...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# #### Converting ratings into number

# %%
titles['rating']= pd.to_numeric(titles['rating'])

# %% [markdown]
# #### Removing special characters from title column

# %%
titles['mod_tit'] = titles['title'].str.replace('[^a-zA-Z)-9 ]','',regex=True)

# %% [markdown]
# #### Convert title colimn to lowecase

# %%
titles['mod_tit'] = titles['mod_tit'].str.lower()

# %% [markdown]
# #### Remove consecutive spaces into one space

# %%
titles['mod_tit'] = titles['mod_tit'].str.replace('\s+',' ',regex=True)

# %% [markdown]
# #### Remove rows with no title

# %%
titles = titles[titles['mod_tit'].str.len()> 0]

# %%
titles.to_json('book-recommendation/book_titles.json')

# %%
titles.head(4)
# Out:
#    book_id                                              title  rating  \
# 0  1333909                                        Good Harbor      10
# 1  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...     140
# 2  6066819                               Best Friends Forever   51184
# 3   287140  Runic Astrology: Starcraft and Timekeeping in ...      15
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1333909.Go...
# 1  https://www.goodreads.com/book/show/7327624-th...
# 2  https://www.goodreads.com/book/show/6066819-be...
# 3  https://www.goodreads.com/book/show/287140.Run...
#
#                                           book_cover  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...
# 1  https://images.gr-assets.com/books/1304100136m...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1413219371m...
#
#                                              mod_tit
# 0                                        good harbor
# 1  the unschooled wizard sun wolf and starhawk, 1-2)
# 2                               best friends forever
# 3  runic astrology starcraft and timekeeping in t...

# %% [markdown]
# ## Building the search engine
# To build the search engine, we need to make a tf-idf matrix of book titles and also we need to find a similarity metric to calculate the simillarity between the search query and tf-idf matrix.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(titles['mod_tit'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re  #regex


#adding a link to url in goodreads
def show_url(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val)


def search(query, vectorizer):
    
    process_query = re.sub('[^A-Za-z0-9 ]','',query.lower()) #remove special chars from query and convert to lowercase
    query_vec = vectorizer.transform([process_query]) #vectorize the query
    similarity = cosine_similarity(query_vec,tfidf).flatten() #calculate cosine similarity
    indices = np.argpartition(similarity,-10)[-10:] #get indices of most relevant books 
    results = titles.iloc[indices] 
    results = results.sort_values('rating',ascending =False)
    return results.head(5).style.format({'url':show_url,'book_cover':show_image})#return 5 most relavent books

# %%
search('franny and zooey', vectorizer)
# Out:
# <style  type="text/css" >
# </style><table id="T_f488b8dd_9062_11ec_9da2_9829a64a6340" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >book_id</th>        <th class="col_heading level0 col1" >title</th>        <th class="col_heading level0 col2" >rating</th>        <th class="col_heading level0 col3" >url</th>        <th class="col_heading level0 col4" >book_cover</th>        <th class="col_heading level0 col5" >mod_tit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f488b8dd_9062_11ec_9da2_9829a64a6340level0_row0" class="row_heading level0 row0" >477424</th>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row0_col0" class="data row0 col0" >77531</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row0_col1" class="data row0 col1" >Franny and Zooey</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row0_col2" class="data row0 col2" >3549</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/77531.Franny_and_Zooey">Goodreads</a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row0_col4" class="data row0 col4" ><a href="https://images.gr-assets.com/books/1229566527m/77531.jpg"><img src="https://images.gr-assets.com/books/1229566527m/77531.jpg" width=50></img></a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row0_col5" class="data row0 col5" >franny and zooey</td>
#             </tr>
#             <tr>
#                         <th id="T_f488b8dd_9062_11ec_9da2_9829a64a6340level0_row1" class="row_heading level0 row1" >284354</th>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row1_col0" class="data row1 col0" >7710230</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row1_col1" class="data row1 col1" >Franny and Zooey</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row1_col2" class="data row1 col2" >871</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/7710230-franny-and-zooey">Goodreads</a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row1_col4" class="data row1 col4" ><a href="https://images.gr-assets.com/books/1278043398m/7710230.jpg"><img src="https://images.gr-assets.com/books/1278043398m/7710230.jpg" width=50></img></a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row1_col5" class="data row1 col5" >franny and zooey</td>
#             </tr>
#             <tr>
#                         <th id="T_f488b8dd_9062_11ec_9da2_9829a64a6340level0_row2" class="row_heading level0 row2" >543301</th>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row2_col0" class="data row2 col0" >884056</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row2_col1" class="data row2 col1" >Franny and Zooey</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row2_col2" class="data row2 col2" >356</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/884056.Franny_and_Zooey">Goodreads</a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row2_col4" class="data row2 col4" ><a href="https://images.gr-assets.com/books/1265654343m/884056.jpg"><img src="https://images.gr-assets.com/books/1265654343m/884056.jpg" width=50></img></a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row2_col5" class="data row2 col5" >franny and zooey</td>
#             </tr>
#             <tr>
#                         <th id="T_f488b8dd_9062_11ec_9da2_9829a64a6340level0_row3" class="row_heading level0 row3" >929057</th>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row3_col0" class="data row3 col0" >2417959</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row3_col1" class="data row3 col1" >Franny and Zooey</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row3_col2" class="data row3 col2" >90</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/2417959.Franny_and_Zooey">Goodreads</a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row3_col4" class="data row3 col4" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row3_col5" class="data row3 col5" >franny and zooey</td>
#             </tr>
#             <tr>
#                         <th id="T_f488b8dd_9062_11ec_9da2_9829a64a6340level0_row4" class="row_heading level0 row4" >937818</th>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row4_col0" class="data row4 col0" >9793805</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row4_col1" class="data row4 col1" >Franny and Zooey</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row4_col2" class="data row4 col2" >83</td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/9793805-franny-and-zooey">Goodreads</a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row4_col4" class="data row4 col4" ><a href="https://images.gr-assets.com/books/1327559219m/9793805.jpg"><img src="https://images.gr-assets.com/books/1327559219m/9793805.jpg" width=50></img></a></td>
#                         <td id="T_f488b8dd_9062_11ec_9da2_9829a64a6340row4_col5" class="data row4 col5" >franny and zooey</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Building the recommendation system
# In order to build the recomm system we need to have a list of books that we liked. Then find users of goodreads that also liked those books(ratings over 4). the next step is to find the liked books of readers with similar taste. This way it is possible to recommend similar books to our liked books

# %% [markdown]
# #### Creating list of liked books

# %%
search('rumi',vectorizer)
# Out:
# <style  type="text/css" >
# </style><table id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >book_id</th>        <th class="col_heading level0 col1" >title</th>        <th class="col_heading level0 col2" >rating</th>        <th class="col_heading level0 col3" >url</th>        <th class="col_heading level0 col4" >book_cover</th>        <th class="col_heading level0 col5" >mod_tit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340level0_row0" class="row_heading level0 row0" >244457</th>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row0_col0" class="data row0 col0" >265540</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row0_col1" class="data row0 col1" >Rumi: Poems</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row0_col2" class="data row0 col2" >556</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/265540.Rumi">Goodreads</a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row0_col4" class="data row0 col4" ><a href="https://images.gr-assets.com/books/1320479183m/265540.jpg"><img src="https://images.gr-assets.com/books/1320479183m/265540.jpg" width=50></img></a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row0_col5" class="data row0 col5" >rumi poems</td>
#             </tr>
#             <tr>
#                         <th id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340level0_row1" class="row_heading level0 row1" >1427808</th>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row1_col0" class="data row1 col0" >67381</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row1_col1" class="data row1 col1" >The Rumi Collection</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row1_col2" class="data row1 col2" >385</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/67381.The_Rumi_Collection">Goodreads</a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row1_col4" class="data row1 col4" ><a href="https://images.gr-assets.com/books/1320517236m/67381.jpg"><img src="https://images.gr-assets.com/books/1320517236m/67381.jpg" width=50></img></a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row1_col5" class="data row1 col5" >the rumi collection</td>
#             </tr>
#             <tr>
#                         <th id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340level0_row2" class="row_heading level0 row2" >1005530</th>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row2_col0" class="data row2 col0" >20211434</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row2_col1" class="data row2 col1" >The Essential Rumi</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row2_col2" class="data row2 col2" >320</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/20211434-the-essential-rumi">Goodreads</a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row2_col4" class="data row2 col4" ><a href="https://images.gr-assets.com/books/1469285546m/20211434.jpg"><img src="https://images.gr-assets.com/books/1469285546m/20211434.jpg" width=50></img></a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row2_col5" class="data row2 col5" >the essential rumi</td>
#             </tr>
#             <tr>
#                         <th id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340level0_row3" class="row_heading level0 row3" >1167949</th>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row3_col0" class="data row3 col0" >67373</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row3_col1" class="data row3 col1" >The Essential Rumi</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row3_col2" class="data row3 col2" >250</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/67373.The_Essential_Rumi">Goodreads</a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row3_col4" class="data row3 col4" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row3_col5" class="data row3 col5" >the essential rumi</td>
#             </tr>
#             <tr>
#                         <th id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340level0_row4" class="row_heading level0 row4" >886000</th>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row4_col0" class="data row4 col0" >25477771</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row4_col1" class="data row4 col1" >The Essential Rumi</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row4_col2" class="data row4 col2" >101</td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/25477771-the-essential-rumi">Goodreads</a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row4_col4" class="data row4 col4" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#                         <td id="T_6ba7a3e2_9062_11ec_a47d_9829a64a6340row4_col5" class="data row4 col5" >the essential rumi</td>
#             </tr>
#     </tbody></table>

# %%
liked = ['265540','7967885','77531']

# %% [markdown]
# #### Mapping book-id in book json file with book-id in goodread interaction file

# %%
book_mapping = {}
with open('book-recommendation/book_id_map.csv','r') as f:
    while True:
        l = f.readline()
        if not l:
            break
        
        book_id_csv, book_id = l.strip().split(',')  #strip() remove any new line chars
        book_mapping[book_id_csv] = book_id

# %%
len(book_mapping)
# Out:
# 2360651

# %% [markdown]
# #### Finding user with the same taste

# %%
users = set()
with open('book-recommendation/goodreads_interactions.csv','r') as f:
    while True:
        l = f.readline()
        if not l:
            break
            
        user_id,csv_id,_,rating,_ = l.split(',')
        if user_id in users:
            continue
        try:
            rating = int(rating)
        except ValueError:
            continue
            
        book_id = book_mapping[csv_id]
        if book_id in liked and rating >= 4:
            users.add(user_id)

# %%
rec_books = []
with open('book-recommendation/goodreads_interactions.csv','r') as f:
    while True:
        l = f.readline()
        if not l:
            break
        user_id,csv_id,_,rating,_ = l.split(',')
        if user_id in users:
            book_id = book_mapping[csv_id]
            rec_books.append([user_id,book_id,rating])

# %% [markdown]
# #### Convert recommended array into dataframe

# %%
recomms = pd.DataFrame(rec_books,columns =['user_id','book_id','rating'])
recomms['book_id'] = recomms['book_id'].astype(str)

# %%
recomms.to_csv('book-recommendation/recommended_books.csv')

# %% [markdown]
# #### Find top recommended books

# %%
top_rec = recomms['book_id'].value_counts().head(10)
top_rec = top_rec.index.values

# %% [markdown]
# #### Finding book titles related to recommended book ids

# %%
book_titles = pd.read_json('book-recommendation/book_titles.json')
book_titles['book_id'] = book_titles['book_id'].astype(str)
book_titles.head(5)
# Out:
#    book_id                                              title  rating  \
# 0  1333909                                        Good Harbor      10
# 1  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...     140
# 2  6066819                               Best Friends Forever   51184
# 3   287140  Runic Astrology: Starcraft and Timekeeping in ...      15
# 4   287141                      The Aeneid for Boys and Girls      46
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1333909.Go...
# 1  https://www.goodreads.com/book/show/7327624-th...
# 2  https://www.goodreads.com/book/show/6066819-be...
# 3  https://www.goodreads.com/book/show/287140.Run...
# 4  https://www.goodreads.com/book/show/287141.The...
#
#                                           book_cover  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...
# 1  https://images.gr-assets.com/books/1304100136m...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1413219371m...
# 4  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                              mod_tit
# 0                                        good harbor
# 1  the unschooled wizard sun wolf and starhawk, 1-2)
# 2                               best friends forever
# 3  runic astrology starcraft and timekeeping in t...
# 4                      the aeneid for boys and girls

# %% [markdown]
# #### Find the titles of recommended books

# %%
book_titles[book_titles['book_id'].isin(top_rec)]
# Out:
#          book_id                                              title   rating  \
# 386663   2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 477424     77531                                   Franny and Zooey     3549
# 546297      5107                             The Catcher in the Rye  2086945
# 630937      4671                                   The Great Gatsby  2758812
# 838525      5470                                               1984  2023937
# 1048745     7613                                        Animal Farm  1928931
# 1077226     2657                              To Kill a Mockingbird  3255518
# 1196415        3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 1229158   136251  Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 1354988    15881  Harry Potter and the Chamber of Secrets (Harry...  1821802
#
#                                                        url  \
# 386663   https://www.goodreads.com/book/show/2767052-th...
# 477424   https://www.goodreads.com/book/show/77531.Fran...
# 546297   https://www.goodreads.com/book/show/5107.The_C...
# 630937   https://www.goodreads.com/book/show/4671.The_G...
# 838525       https://www.goodreads.com/book/show/5470.1984
# 1048745  https://www.goodreads.com/book/show/7613.Anima...
# 1077226  https://www.goodreads.com/book/show/2657.To_Ki...
# 1196415  https://www.goodreads.com/book/show/3.Harry_Po...
# 1229158  https://www.goodreads.com/book/show/136251.Har...
# 1354988  https://www.goodreads.com/book/show/15881.Harr...
#
#                                                 book_cover  \
# 386663   https://images.gr-assets.com/books/1447303603m...
# 477424   https://images.gr-assets.com/books/1229566527m...
# 546297   https://images.gr-assets.com/books/1398034300m...
# 630937   https://images.gr-assets.com/books/1490528560m...
# 838525   https://images.gr-assets.com/books/1348990566m...
# 1048745  https://images.gr-assets.com/books/1424037542m...
# 1077226  https://images.gr-assets.com/books/1361975680m...
# 1196415  https://images.gr-assets.com/books/1474154022m...
# 1229158  https://images.gr-assets.com/books/1474171184m...
# 1354988  https://images.gr-assets.com/books/1474169725m...
#
#                                                    mod_tit
# 386663               the hunger games the hunger games, 1)
# 477424                                    franny and zooey
# 546297                              the catcher in the rye
# 630937                                    the great gatsby
# 838525                                                1984
# 1048745                                        animal farm
# 1077226                              to kill a mockingbird
# 1196415  harry potter and the sorcerers stone harry pot...
# 1229158  harry potter and the deathly hallows harry pot...
# 1354988  harry potter and the chamber of secrets harry ...

# %% [markdown]
# ## Making the recommendatiom more personalised

# %%
all_rec = recomms['book_id'].value_counts()

# %%
all_rec
# Out:
# 77531       305
# 4671        277
# 2657        245
# 5470        245
# 5107        231
#            ...
# 7179451       1
# 23260922      1
# 237704        1
# 20609217      1
# 531408        1
# Name: book_id, Length: 220824, dtype: int64

# %%
all_rec
# Out:
# 77531       305
# 4671        277
# 2657        245
# 5470        245
# 5107        231
#            ...
# 7179451       1
# 23260922      1
# 237704        1
# 20609217      1
# 531408        1
# Name: book_id, Length: 220824, dtype: int64

# %%
all_rec =all_rec.to_frame()

# %%
 all_rec = all_rec.reset_index()
all_rec
# Out:
#            index  book_id
# 0          77531      305
# 1           4671      277
# 2           2657      245
# 3           5470      245
# 4           5107      231
# ...          ...      ...
# 220819   7179451        1
# 220820  23260922        1
# 220821    237704        1
# 220822  20609217        1
# 220823    531408        1
#
# [220824 rows x 2 columns]

# %%
all_rec.columns = ['book_id','book_count']
all_rec
# Out:
#          book_id  book_count
# 0          77531         305
# 1           4671         277
# 2           2657         245
# 3           5470         245
# 4           5107         231
# ...          ...         ...
# 220819   7179451           1
# 220820  23260922           1
# 220821    237704           1
# 220822  20609217           1
# 220823    531408           1
#
# [220824 rows x 2 columns]

# %% [markdown]
# #### Merging all recommendations with our book title dataframe

# %%
all_rec = all_rec.merge(book_titles, how='inner',on='book_id')

# %% [markdown]
# #### Define a score for each book based on counts and penalize the book if it is very popular(divide by the number of ratings)

# %%
all_rec['score'] = all_rec['book_count']*(all_rec['book_count']/all_rec['rating'])

# %%
all_rec.sort_values('score', ascending=False)
# Out:
#          book_id  book_count  \
# 0          77531         305
# 32       7967885         155
# 238       265540          69
# 450        77530          48
# 15009   32191854           4
# ...          ...         ...
# 210087  16140036           1
# 189690  20448515           1
# 74843     784911           1
# 148726    411053           1
# 119459  11260526           1
#
#                                                     title  rating  \
# 0                                        Franny and Zooey    3549
# 32                                 The Catcher in the Rye    1538
# 238                                           Rumi: Poems     556
# 450     Raise High the Roof Beam, Carpenters and Seymo...     843
# 15009   Vulgar Tongues: An Alternative History of Engl...       6
# ...                                                   ...     ...
# 210087                            This Man (This Man, #1)   80440
# 189690                       Bared to You (Crossfire, #1)   84614
# 74843           Rise of the Evening Star (Fablehaven, #2)   84861
# 148726             Better Homes and Gardens New Cook Book   97060
# 119459  The Twilight Saga Breaking Dawn Part 1: The Of...  203853
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/77531.Fran...
# 32      https://www.goodreads.com/book/show/7967885-th...
# 238       https://www.goodreads.com/book/show/265540.Rumi
# 450     https://www.goodreads.com/book/show/77530.Rais...
# 15009   https://www.goodreads.com/book/show/32191854-v...
# ...                                                   ...
# 210087  https://www.goodreads.com/book/show/16140036-t...
# 189690  https://www.goodreads.com/book/show/20448515-b...
# 74843   https://www.goodreads.com/book/show/784911.Ris...
# 148726  https://www.goodreads.com/book/show/411053.Bet...
# 119459  https://www.goodreads.com/book/show/11260526-t...
#
#                                                book_cover  \
# 0       https://images.gr-assets.com/books/1229566527m...
# 32      https://images.gr-assets.com/books/1327197188m...
# 238     https://images.gr-assets.com/books/1320479183m...
# 450     https://s.gr-assets.com/assets/nophoto/book/11...
# 15009   https://images.gr-assets.com/books/1477088826m...
# ...                                                   ...
# 210087  https://images.gr-assets.com/books/1352790466m...
# 189690  https://images.gr-assets.com/books/1433411511m...
# 74843   https://images.gr-assets.com/books/1386633982m...
# 148726  https://s.gr-assets.com/assets/nophoto/book/11...
# 119459  https://images.gr-assets.com/books/1327904795m...
#
#                                                   mod_tit      score
# 0                                        franny and zooey  26.211609
# 32                                 the catcher in the rye  15.620936
# 238                                            rumi poems   8.562950
# 450     raise high the roof beam, carpenters and seymo...   2.733096
# 15009   vulgar tongues an alternative history of engli...   2.666667
# ...                                                   ...        ...
# 210087                              this man this man, 1)   0.000012
# 189690                         bared to you crossfire, 1)   0.000012
# 74843             rise of the evening star fablehaven, 2)   0.000012
# 148726             better homes and gardens new cook book   0.000010
# 119459  the twilight saga breaking dawn part 1 the off...   0.000005
#
# [212225 rows x 8 columns]

# %%
popular_recs = all_rec[all_rec['book_count'] > 75].sort_values('score', ascending =False).head(10)

# %%
popular_recs
# Out:
#      book_id  book_count                   title  rating  \
# 0      77531         305        Franny and Zooey    3549
# 32   7967885         155  The Catcher in the Rye    1538
# 160    77532          83            Nine Stories    3251
# 163     6759          82           Infinite Jest   47926
# 171    18521          80     A Room of One's Own   61613
# 88     10975         106  The Sound and the Fury  126251
# 164   338798          82                 Ulysses   78309
# 168    46164          81     Tender Is the Night   80994
# 123    77013          92          As I Lay Dying  105220
# 124     4009          92            Nine Stories  105950
#
#                                                    url  \
# 0    https://www.goodreads.com/book/show/77531.Fran...
# 32   https://www.goodreads.com/book/show/7967885-th...
# 160  https://www.goodreads.com/book/show/77532.Nine...
# 163  https://www.goodreads.com/book/show/6759.Infin...
# 171  https://www.goodreads.com/book/show/18521.A_Ro...
# 88   https://www.goodreads.com/book/show/10975.The_...
# 164  https://www.goodreads.com/book/show/338798.Uly...
# 168  https://www.goodreads.com/book/show/46164.Tend...
# 123  https://www.goodreads.com/book/show/77013.As_I...
# 124  https://www.goodreads.com/book/show/4009.Nine_...
#
#                                             book_cover  \
# 0    https://images.gr-assets.com/books/1229566527m...
# 32   https://images.gr-assets.com/books/1327197188m...
# 160  https://images.gr-assets.com/books/1407030892m...
# 163  https://images.gr-assets.com/books/1446876799m...
# 171  https://images.gr-assets.com/books/1327883012m...
# 88   https://images.gr-assets.com/books/1433089995m...
# 164  https://images.gr-assets.com/books/1428891345m...
# 168  https://images.gr-assets.com/books/1438797669m...
# 123  https://images.gr-assets.com/books/1451810782m...
# 124  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                     mod_tit      score
# 0          franny and zooey  26.211609
# 32   the catcher in the rye  15.620936
# 160            nine stories   2.119040
# 163           infinite jest   0.140300
# 171      a room of ones own   0.103874
# 88   the sound and the fury   0.088997
# 164                 ulysses   0.085865
# 168     tender is the night   0.081006
# 123          as i lay dying   0.080441
# 124            nine stories   0.079887

# %%
def show_url(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)
popular_recs[~popular_recs['book_id'].isin(liked)].style.format({'url':show_url,'book_cover':show_image})
# Out:
# <style  type="text/css" >
# </style><table id="T_284101f2_911d_11ec_b112_9822ef89b592" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >book_id</th>        <th class="col_heading level0 col1" >book_count</th>        <th class="col_heading level0 col2" >title</th>        <th class="col_heading level0 col3" >rating</th>        <th class="col_heading level0 col4" >url</th>        <th class="col_heading level0 col5" >book_cover</th>        <th class="col_heading level0 col6" >mod_tit</th>        <th class="col_heading level0 col7" >score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_284101f2_911d_11ec_b112_9822ef89b592level0_row0" class="row_heading level0 row0" >160</th>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col0" class="data row0 col0" >77532</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col1" class="data row0 col1" >83</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col2" class="data row0 col2" >Nine Stories</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col3" class="data row0 col3" >3251</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/77532.Nine_Stories">Goodreads</a></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col5" class="data row0 col5" ><img src="https://images.gr-assets.com/books/1407030892m/77532.jpg" width=50></img></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col6" class="data row0 col6" >nine stories</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row0_col7" class="data row0 col7" >2.119040</td>
#             </tr>
#             <tr>
#                         <th id="T_284101f2_911d_11ec_b112_9822ef89b592level0_row1" class="row_heading level0 row1" >163</th>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col0" class="data row1 col0" >6759</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col1" class="data row1 col1" >82</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col2" class="data row1 col2" >Infinite Jest</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col3" class="data row1 col3" >47926</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/6759.Infinite_Jest">Goodreads</a></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col5" class="data row1 col5" ><img src="https://images.gr-assets.com/books/1446876799m/6759.jpg" width=50></img></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col6" class="data row1 col6" >infinite jest</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row1_col7" class="data row1 col7" >0.140300</td>
#             </tr>
#             <tr>
#                         <th id="T_284101f2_911d_11ec_b112_9822ef89b592level0_row2" class="row_heading level0 row2" >171</th>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col0" class="data row2 col0" >18521</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col1" class="data row2 col1" >80</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col2" class="data row2 col2" >A Room of One's Own</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col3" class="data row2 col3" >61613</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/18521.A_Room_of_One_s_Own">Goodreads</a></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col5" class="data row2 col5" ><img src="https://images.gr-assets.com/books/1327883012m/18521.jpg" width=50></img></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col6" class="data row2 col6" >a room of ones own</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row2_col7" class="data row2 col7" >0.103874</td>
#             </tr>
#             <tr>
#                         <th id="T_284101f2_911d_11ec_b112_9822ef89b592level0_row3" class="row_heading level0 row3" >88</th>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col0" class="data row3 col0" >10975</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col1" class="data row3 col1" >106</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col2" class="data row3 col2" >The Sound and the Fury</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col3" class="data row3 col3" >126251</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/10975.The_Sound_and_the_Fury">Goodreads</a></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col5" class="data row3 col5" ><img src="https://images.gr-assets.com/books/1433089995m/10975.jpg" width=50></img></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col6" class="data row3 col6" >the sound and the fury</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row3_col7" class="data row3 col7" >0.088997</td>
#             </tr>
#             <tr>
#                         <th id="T_284101f2_911d_11ec_b112_9822ef89b592level0_row4" class="row_heading level0 row4" >164</th>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col0" class="data row4 col0" >338798</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col1" class="data row4 col1" >82</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col2" class="data row4 col2" >Ulysses</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col3" class="data row4 col3" >78309</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/338798.Ulysses">Goodreads</a></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col5" class="data row4 col5" ><img src="https://images.gr-assets.com/books/1428891345m/338798.jpg" width=50></img></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col6" class="data row4 col6" >ulysses</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row4_col7" class="data row4 col7" >0.085865</td>
#             </tr>
#             <tr>
#                         <th id="T_284101f2_911d_11ec_b112_9822ef89b592level0_row5" class="row_heading level0 row5" >168</th>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row5_col0" class="data row5 col0" >46164</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row5_col1" class="data row5 col1" >81</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row5_col2" class="data row5 col2" >Tender Is the Night</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row5_col3" class="data row5 col3" >80994</td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/46164.Tender_Is_the_Night">Goodreads</a></td>
#                         <td id="T_284101f2_911d_11ec_b112_9822ef89b592row5_col5" class="data row5 col5" ><img src="https://images.gr-assets.com/books/1438797669m/4616
